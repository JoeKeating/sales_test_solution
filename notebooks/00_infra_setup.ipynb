# %% [markdown]
# #Setup
#
# Goal: Create Databricks catalog and schemas for bronze, silver and gold layers.

# %% [markdown]
# ## Create Databricks Catalog and Schema

# %% [markdown]
# ### Create sales catalog

# %%
# %sql
CREATE CATALOG IF NOT EXISTS sales;

# %% [markdown]
# ### Create schemas

# %%
# %sql

USE CATALOG sales;

CREATE SCHEMA IF NOT EXISTS bronze;
CREATE SCHEMA IF NOT EXISTS silver;
CREATE SCHEMA IF NOT EXISTS gold;
